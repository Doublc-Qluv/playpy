# %% [markdown]
# <font color=#ff00ff size=5 face="黑体"> 首先请提前阅读本次实验的实验目的、实验内容、实验环境、实验原理和实验步骤；接着按照下面的笔记和要求，运行代码，并编写自己的代码；在实验的过程中，请把碰到的问题，解决方案，心得等等做好笔记。</font>

# %% [markdown]
# ### 通过了解古登堡计划(最古老的数字图书馆)，学习如何进行简单地文本处理。
# ### Project Gutenberg: http://www.gutenberg.org/

# %% [markdown]
# <font color=#0000ff size=5 face="黑体"> 准备数据</font>
#
# 1) 解压文件 Books_GerPort.zip 和 Books_EngFr.zip；
#
# 2) 把解压后的两个文件夹中的所有文件和目录移动到一个新的目录中，命名为 Books；
#
# 3) 在文件夹Books中，删除所有的以 .DS_Store 开头或命名的文件和文件夹。

# %% [markdown]
# <font color=#0000ff size=5 face="黑体"> 我们的目标是写一个函数，来统计一段文本中每个单词出现的次数，跟踪单词的最好的实现方式是什么？</font>

# %%
# Python dictionaries are a very natural choice；
# the keys are the words containing in the input text;
# all words are transformed into lowercase;
# the values are numbers indicating how many times each word appears in the text;

# create a function named count_words with a parameter text;
# the function return a dictionary named word_counts;

def count_words(text):
    """
    Count the number of times each word occurs in text(str). Return dictionary where keys are unique
    words and values are word counts. Skip punctuation(.,;:'"). Change all the character into lowercase.
    """
    # your code is here
    counts={}
    text=text.lower()
    for ch in '\.\,\;\:\'\"':
        text=text.replace(ch,"")
    words=text.split()
    for word in words:
        counts[word]=counts.get(word,0)+1
    
    return counts

# %% [markdown]
# <font color=#ff0000 size=5 face="黑体">在上面函数的实现过程中，会存在一种情况，比如don't， we're这样的缩写，在删除了所有的标点符号后，就会变为dont,were。为了简单，我们不做过多地处理，认为删除标点符号之后的dont,were就是一个单词。</font>

# %%
# counting words
text = "This is my test text. We're keeping this text short to keep things manageable."
print(count_words(text))
# Out:
# {'this': 2, 'is': 1, 'my': 1, 'test': 1, 'text': 2, 'were': 1, 'keeping': 1, 'short': 1, 'to': 1, 'keep': 1, 'things': 1, 'manageable': 1}

# %% [markdown]
# <font color=#0000ff size=5 face="黑体"> 学习怎样使用模块collections中的Counter来实现相同的任务</font>

# %%
from collections import Counter

def count_words_fast(text):
    """
    Count the number of times each word occurs in text(str). Return dictionary where keys are unique
    words and values are word counts.Skip punctuation(.,;:'"). Change all the character into lowercase. 
    """
    # copy a part of lines from the function you defined above
    text=text.lower()
    for ch in '\.\,\;\:\'\"': #':/~!@#$%^&*()_+-\"{}[]|?.<>?\'':
        text=text.replace(ch,"")
    # code for creating the dictionary can be replaced by the following line
    word_counts = Counter(text.split(" ")) 
    return word_counts

# %%
count_words_fast(text)
# Out:
# Counter({'this': 2,
#          'is': 1,
#          'my': 1,
#          'test': 1,
#          'text': 2,
#          'were': 1,
#          'keeping': 1,
#          'short': 1,
#          'to': 1,
#          'keep': 1,
#          'things': 1,
#          'manageable': 1})

# %%
count_words(text) == count_words_fast(text)
# Out:
# True

# %% [markdown]
# <font color=#0000ff size=5 face="黑体"> 学习怎样通过文件路径来获取文件的内容</font>

# %%
# define a fuction named read_book, with a parameter title_path which is the path of a book;
# the function will read the content of a book as a string;
# then remove the "\n" and "\r" in the string and return the string;
# in order to process the certain characters in file path, we need to 
# add encoding='utf8' in open()
def read_book(title_path):
    """
    Read a book and return it as a string.
    """
    # your code is here
    fr = open(title_path, 'r', encoding='UTF-8')
    context = fr.read()
    context = context.replace('\n',"")
    context = context.replace('\r',"")
    return context

# %%
text = read_book("./Books/English/shakespeare/Romeo and Juliet.txt")
print(text)
# Out:
# ﻿The Project Gutenberg EBook of Romeo and Juliet, by William ShakespeareThis eBook is for the use of anyone anywhere at no cost and withalmost no restrictions whatsoever.  You may copy it, give it away orre-use it under the terms of the Project Gutenberg License includedwith this eBook or online at www.gutenberg.org/licenseTitle: Romeo and JulietAuthor: William ShakespearePosting Date: May 25, 2012 [EBook #1112]Release Date: November, 1997  [Etext #1112]Language: English*** START OF THIS PROJECT GUTENBERG EBOOK ROMEO AND JULIET ****Project Gutenberg is proud to cooperate with The World Library*in the presentation of The Complete Works of William Shakespearefor your reading for education and entertainment.  HOWEVER, THISIS NEITHER SHAREWARE NOR PUBLIC DOMAIN. . .AND UNDER THE LIBRARYOF THE FUTURE CONDITIONS OF THIS PRESENTATION. . .NO CHARGES MAYBE MADE FOR *ANY* ACCESS TO THIS MATERIAL.  YOU ARE ENCOURAGED!!TO GIVE IT AWAY TO ANYONE YOU LIKE, BUT NO CHARGES ARE ALLOWED!!The Complete Works of William ShakespeareThe Tragedy of Romeo and JulietThe Library of the Future Complete Works of William ShakespeareLibrary of the Future is a TradeMark (TM) of World Library Inc.<<THIS ELECTRONIC VERSION OF THE COMPLETE WORKS OF WILLIAMSHAKESPEARE IS COPYRIGHT 1990-1993 BY WORLD LIBRARY, INC., AND ISPROVIDED BY PROJECT GUTENBERG ETEXT OF CARNEGIE MELLON UNIVERSITYWITH PERMISSION.  ELECTRONIC AND MACHINE READABLE COPIES MAY BEDISTRIBUTED SO LONG AS SUCH COPIES (1) ARE FOR YOUR OR OTHERSPERSONAL USE ONLY, AND (2) ARE NOT DISTRIBUTED OR USEDCOMMERCIALLY.  PROHIBITED COMMERCIAL DISTRIBUTION INCLUDES BY ANYSERVICE THAT CHARGES FOR DOWNLOAD TIME OR FOR MEMBERSHIP.>>1595THE TRAGEDY OF ROMEO AND JULIETby William ShakespeareDramatis Personae  Chorus.  Escalus, Prince of Verona.  Paris, a young Count, kinsman to the Prince.  Montague, heads of two houses at variance with each other.  Capulet, heads of two houses at variance with each other.  An old Man, of the Capulet family.  Romeo, son to Montague.  Tybalt, nephew to Lady Capulet.  Mercutio, kinsman to the Prince and friend to Romeo.  Benvolio, nephew to Montague, and friend to Romeo  Tybalt, nephew to Lady Capulet.  Friar Laurence, Franciscan.  Friar John, Franciscan.  Balthasar, servant to Romeo.  Abram, servant to Montague.  Sampson, servant to Capulet.  Gregory, servant to Capulet.  Peter, servant to Juliet's nurse.  An Apothecary.  Three Musicians.  An Officer.  Lady Montague, wife to Montague.  Lady Capulet, wife to Capulet.  Juliet, daughter to Capulet.  Nurse to Juliet.  Citizens of Verona; Gentlemen and Gentlewomen of both houses;    Maskers, Torchbearers, Pages, Guards, Watchmen, Servants, and    Attendants.                            SCENE.--Verona; Mantua.                        THE PROLOGUE                        Enter Chorus.  Chor. Two households, both alike in dignity,    In fair Verona, where we lay our scene,    From ancient grudge break to new mutiny,    Where civil blood makes civil hands unclean.    From forth the fatal loins of these two foes    A pair of star-cross'd lovers take their life;    Whose misadventur'd piteous overthrows    Doth with their death bury their parents' strife.    The fearful passage of their death-mark'd love,    And the continuance of their parents' rage,    Which, but their children's end, naught could remove,    Is now the two hours' traffic of our stage;    The which if you with patient ears attend,    What here shall miss, our toil shall strive to mend.                                                         [Exit.]ACT I. Scene I.Verona. A public place.Enter Sampson and Gregory (with swords and bucklers) of the houseof Capulet.  Samp. Gregory, on my word, we'll not carry coals.  Greg. No, for then we should be colliers.  Samp. I mean, an we be in choler, we'll draw.  Greg. Ay, while you live, draw your neck out of collar.  Samp. I strike quickly, being moved.  Greg. But thou art not quickly moved to strike.  Samp. A dog of the house of Montague mov ...

# %%
# try reading in Shakespeare's Romeo and Juliet
text = read_book("./Books/English/shakespeare/Romeo and Juliet.txt")

# %%
len(text) # 169275
# Out:
# 169275

# %%
# there's a famous line in Romeo and Juliet: What's in a name?
# Let's see if we can find its index from text;
# set the value to ind
ind = text.index('What\'s in a name?')
print(ind)
# print ind 
# 42757 is the result
# Out:
# 42757

# %%
# extract a sample text named sample_text from text;
# sample_text contains 1,000 characters from ind.
sample_text = text[ind:ind+1000]
# print sample_text
print(sample_text)
# Out:
# What's in a name? That which we call a rose    By any other name would smell as sweet.    So Romeo would, were he not Romeo call'd,    Retain that dear perfection which he owes    Without that title. Romeo, doff thy name;    And for that name, which is no part of thee,    Take all myself.  Rom. I take thee at thy word.    Call me but love, and I'll be new baptiz'd;    Henceforth I never will be Romeo.  Jul. What man art thou that, thus bescreen'd in night,    So stumblest on my counsel?  Rom. By a name    I know not how to tell thee who I am.    My name, dear saint, is hateful to myself,    Because it is an enemy to thee.    Had I it written, I would tear the word.  Jul. My ears have yet not drunk a hundred words    Of that tongue's utterance, yet I know the sound.    Art thou not Romeo, and a Montague?  Rom. Neither, fair saint, if either thee dislike.  Jul. How cam'st thou hither, tell me, and wherefore?    The orchard walls are high and hard to climb,    And the place death, conside

# %% [markdown]
# <font color=#0000ff size=5 face="黑体"> 学习怎样统计单词的频率</font>

# %%
# define a function named word_statistics with a parameter word_counts;
# word_counts is a dictionary which is returned by the previous function count_words or count_words_fast;
# the function return a tuple: (the number of unique words, the frequency of these unique words)
# complete this function

def word_statistics(word_counts):#lactre dic
    """
    Return number of unique words and word frequencies.
    """
    # the number of unique words
    num_unique = len(word_counts)
    # the frequency of each unique words, invoke values()
    counts = word_counts.values()
    return (num_unique,counts)

# %%
# reading the book Romeo and Juliet
text = read_book("./Books/English/shakespeare/Romeo and Juliet.txt")
# count the words
word_counts = count_words_fast(text)
# return the number of unique words and the word frequencies
(num_unique,counts) = word_statistics(word_counts)
print(word_counts)
print(num_unique,sum(counts)) # (5118, 40776)
# Out:
# Counter({'': 12183, 'the': 834, 'and': 777, 'to': 606, 'i': 577, 'of': 527, 'a': 509, 'in': 374, 'is': 367, 'my': 360, 'that': 355, 'you': 348, 'with': 286, 'not': 277, 'thou': 275, 'this': 257, 'for': 254, 'me': 243, 'it': 235, 'be': 226, 'but': 189, 'as': 166, 'thy': 164, 'rom': 163, 'what': 160, 'will': 152, 'o': 152, 'her': 151, 'so': 141, 'his': 139, 'or': 137, 'nurse': 136, 'have': 130, 'thee': 129, 'by': 126, 'love': 120, 'he': 119, 'jul': 117, 'romeo': 116, 'no': 112, 'shall': 112, 'your': 111, 'she': 111, 'all': 110, 'do': 102, 'if': 100, 'from': 96, 'come': 94, 'him': 92, 'are': 88, 'an': 88, 'on': 87, 'friar': 84, 'ill': 83, 'at': 82, 'good': 82, 'then': 81, 'we': 73, 'now': 73, 'go': 73, 'here': 72, 'which': 70, 'project': 67, 'well': 67, 'more': 67, 'our': 65, 'may': 64, 'ben': 64, 'hath': 64, 'death': 63, 'night': 63, 'man': 62, 'how': 62, 'mer': 62, 'lady': 61, 'one': 61, 'they': 61, 'am': 60, 'there': 60, 'enter': 58, 'juliet': 57, 'some': 57, 'would': 56, 'where': 54, 'art': 54, 'when': 54, 'up': 54, 'too': 54, 'cap': 53, 'give': 52, 'out': 52, 'such': 51, 'should': 51, 'tybalt': 50, 'was': 50, 'must': 49, 'say': 49, 'can': 49, 'sir': 48, 'than': 48, 'their': 47, 'doth': 47, 'yet': 47, 'any': 46, 'these': 45, 'let': 45, 'upon': 45, 'tell': 45, 'them': 43, 'wife': 42, 'fair': 42, 'make': 42, 'like': 41, 'take': 41, 'tis': 41, 'work': 40, 'why': 39, 'did': 38, 'see': 38, 'much': 37, 'know': 36, 'were': 36, 'dead': 36, 'prince': 35, 'old': 35, 'gutenberg-tm': 34, 'who': 33, 'paris': 32, 'sweet': 32, 'other': 31, 'day': 31, 'capulet': 30, 'ay': 30, 'wilt': 30, 'time': 29, 'us': 29, 'look': 29, 'mine': 29, 'back': 28, 'hast': 28, 'heaven': 28, 'montague': 27, 'speak': 27, 'eyes': 27, 'use': 26, 'works': 26, 'part': 26, 'light': 26, 'hence': 26, 'very': 26, 'gone': 26, 'word': 25, 'being': 25, 'stand': 25, 'true': 25, 'stay': 25, 'cannot': 25, 'lord': 25, 'mother': 25, 'two': 24, 'comes': 24, 'heart': 24, 'find': 24, 'full': 24, 'gutenberg': 23, 'young': 23, 'both': 23, 'therefore': 23, 'call': 23, 'again': 23, 'father': 23, 'par': 23, 'god': 23, 'hand': 23, 'dear': 23, 'marry': 22, 'hear': 22, 'till': 22, 'bid': 22, 'die': 22, 'away': 21, 'nor': 21, 'made': 21, 'electronic': 21, 'life': 21, 'house': 21, 'before': 21, 'bed': 21, 'holy': 21, 'name': 21, 'terms': 20, 'samp': 20, 'men': 20, 'been': 20, 'nay': 20, 'lie': 20, 'ere': 20, 'mercutio': 19, 'forth': 19, 'live': 19, 'about': 19, 'romeos': 19, 'without': 19, 'think': 19, 'county': 19, 'lies': 19, 'face': 19, 'world': 18, 'long': 18, 'could': 18, 'most': 18, 'ah': 18, 'serv': 18, 'never': 18, 'eye': 18, 'married': 18, 'watch': 18, 'alone': 18, 'down': 17, 'tyb': 17, 'keep': 17, 'hold': 17, 'madam': 17, 'tears': 17, 'farewell': 17, 'poor': 17, 'earth': 17, 'within': 17, 'pray': 17, 'had': 17, 'help': 17, 'son': 16, 'new': 16, 'put': 16, 'peace': 16, 'villain': 16, 'hour': 16, 'early': 16, 'own': 16, 'many': 16, 'dost': 16, 'days': 16, 'agreement': 16, 'friend': 15, 'blood': 15, 'whose': 15, 'greg': 15, 'those': 15, 'set': 15, 'faith': 15, 'lips': 15, 'romeo!': 15, 'foundation': 15, 'under': 14, 'copyright': 14, 'myself': 14, 'fear': 14, 'rest': 14, 'sun': 14, 'me!': 14, 'still': 14, 'loves': 14, 'thine': 14, 'said': 14, 'get': 14, 'none': 14, 'poison': 14, 'exit': 14, 'same': 14, 'fall': 14, '1': 14, 'to-morrow': 14, 'slain': 14, 'day!': 14, 'mus': 14, 'benvolio': 13, 'mantua': 13, 'makes': 13, 'hands': 13, 'grave': 13, 'lives': 13, 'came': 13, 'head': 13, 'nothing': 13, 'soon': 13, 'leave': 13, 'exeuntscene': 13, 'little': 13, 'send': 13, 'letter': 13, 'thursday': 13, 'states': 13, 'donations': 13, 'public': 12, 'only': 12, 'peter': 12, 'daughter': 12, 'ever': 12, 'turn': 12, 'law': 12, 'bear': 12, 'better': 12, 'talk': 12, 'happy': 12, 'gentle': 12, 'sleep': 12, 'grief': 12, 'shes': 12, 'years': 12, 'even': 12, 'best': 12, 'run': 12, 'woe': 12, 'to-night': 12, 'boy': 12, 'joy': 12, 'breath': 12, 'cell': 12, 'banished': 12, 'license': 11, 'verona': 11, 'kinsman' ...
# 5118 40776

# %%
num_unique
# Out:
# 5118

# %%
# print how many words there are in total
sum(counts)
# Out:
# 40776

# %%
# reading the book Romeo and Juliet in German dictionary
fgerman = read_book("./Books/German/shakespeare/Romeo und Julia.txt")
# count the words
word_counts = count_words_fast(fgerman)
# return the number of unique words and the word frequencies
(num_unique,counts) = word_statistics(word_counts)
print(num_unique,sum(counts)) # (7527,20311)
# Out:
# 7527 20311

# %% [markdown]
# <font color=#0000ff size=5 face="黑体"> 学习怎样浏览文件目录并且一次性读取多个文件</font>

# %%
import os
book_dir = "./Books/"
os.listdir(book_dir)
# Out:
# ['German', 'English', 'Portuguese', 'French']

# %%
os.listdir(book_dir+"/"+'English')
# Out:
# ['shakespeare']

# %%
os.listdir(book_dir+"/"+'English'+"/"+'shakespeare')
# Out:
# ['Othello.txt',
#  'Richard III.txt',
#  'The Merchant of Venice.txt',
#  "A Midsummer Night's Dream.txt",
#  'Macbeth.txt',
#  'Hamlet.txt',
#  'Romeo and Juliet.txt']

# %%
# call the loop variable language to print all the books in the dictionary Books

# the first for loop is looping over languages
# the second for loop is looping over authors
# the third, the innermost for loop, is looping over different titles, different books.
# print the path of each book
# record the number of unique words and the word frequencies of each book as (num_unique,counts)
for language in os.listdir(book_dir):  # 将（）中的参数补充完整
    for author in os.listdir(book_dir+"/"+language):  #将（）中的参数补充完整
        for title in os.listdir(book_dir+"/"+language+"/"+author):  #将（）中的参数补充完整
            inputfile =  book_dir+language+"/"+author+"/"+title  # 给inputfile赋值
            text = read_book(inputfile)
            (num_unique,counts) = word_statistics(count_words_fast(text))

# %% [markdown]
# <font color=#0000ff size=5 face="黑体"> 学习怎样使用Pandas库来建立多维结构化的数据</font>
#
# pandas库是一个强大的工具,它有两种主要的数据结构: Series和DataFrame
#
# Series是一种类似与一维数组的对象，它由一组数据以及一组与之相关的数据便签（即索引）组成，仅由一组数据即可产生最简单的Series。
#
# DataFrame是一个表格型数据，含有一组有序的列，每一列可以是不同的类型值。DataFrame可以看成是由多个Series组成的字典，它们共用一个索引。
#
# 参考：[10 Minutes to pandas](https://pandas.pydata.org/pandas-docs/stable/getting_started/10min.html)

# %%
import pandas as pd

# %%
stats = pd.DataFrame(columns = ("language","author","title","length","unique"))
title_num = 1

# %%
# DataFrame.loc[]: Access a group of rows and columns by label(s) or a boolean array.
stats = pd.DataFrame(columns = ("language","author","title","length","unique"))
title_num = 1            


for language in os.listdir(book_dir):  # 将（）中的参数补充完整
    for author in os.listdir(book_dir+"/"+language):  #将（）中的参数补充完整
        for title in os.listdir(book_dir+"/"+language+"/"+author):  #将（）中的参数补充完整
            inputfile =  book_dir+language+"/"+author+"/"+title    # 给inputfile赋值
            text = read_book(inputfile)
            (num_unique,counts) = word_statistics(count_words_fast(text))
            #  insert a row to a dataframe
            stats.loc[title_num] = language, author, title, sum(counts), num_unique 
            title_num += 1

# %%
stats
# Out:
#     language         author  \
# 1     German       schiller
# 2     German       schiller
# 3     German       schiller
# 4     German       schiller
# 5     German       schiller
# 6     German       schiller
# 7     German       schiller
# 8     German       schiller
# 9     German       schiller
# 10    German       schiller
# 11    German       schiller
# 12    German        lessing
# 13    German        lessing
# 14    German        lessing
# 15    German        lessing
# 16    German        lessing
# 17    German        lessing
# 18    German        lessing
# 19    German        lessing
# 20    German        raimund
# 21    German        raimund
# 22    German        raimund
# 23    German        raimund
# 24    German        raimund
# 25    German        raimund
# 26    German        raimund
# 27    German        raimund
# 28    German    shakespeare
# 29    German    shakespeare
# 30    German    shakespeare
# ..       ...            ...
# 73    French  de Maupassant
# 74    French  de Maupassant
# 75    French  de Maupassant
# 76    French  de Maupassant
# 77    French  de Maupassant
# 78    French  de Maupassant
# 79    French  de Maupassant
# 80    French        diderot
# 81    French        diderot
# 82    French        diderot
# 83    French        diderot
# 84    French        diderot
# 85    French      chevalier
# 86    French      chevalier
# 87    French      chevalier
# 88    French      chevalier
# 89    French      chevalier
# 90    French      chevalier
# 91    French      chevalier
# 92    French           sand
# 93    French           sand
# 94    French           sand
# 95    French           sand
# 96    French           sand
# 97    French           sand
# 98    French           sand
# 99    French           sand
# 100   French           sand
# 101   French           sand
# 102   French           sand
#
#                                                  title  length unique
# 1                               Wallensteins Lager.txt   15443   4379
# 2                            die braut von messina.txt   26482   6655
# 3    Der Parasit, oder die Kunst, sein GlÅck zu ma...   20450   6159
# 4            Die Verschwîrung des Fiesco zu Genua.txt   31128  10371
# 5                                 Kabale und Liebe.txt   30929   9969
# 6                        Die Huldigung der KÅnste.txt    3919   1730
# 7                              Der Neffe als Onkel.txt   14349   4416
# 8                                  Die Piccolomini.txt   35456   6763
# 9                         Die Jungfrau von Orleans.txt   24181   8806
# 10                  Turandot, Prinzessin von China.txt   21441   7550
# 11                                Wallensteins Tod.txt   50725   8649
# 12                              minna von barnhelm.txt   23863   7345
# 13                        hamburgische dramaturgie.txt  143699  29192
# 14                               miss sara sampson.txt   28148   7231
# 15                                       die juden.txt   12143   3887
# 16                                   der freigeist.txt   23660   6319
# 17                                        philotas.txt    9535   3278
# 18                              der junge gelehrte.txt   28155   7231
# 19                                  emilia galotti.txt   20484   6631
# 20                                Der Verschwender.txt   25106   7423
# 21                        Die gefesselte Phantasie.txt   16651   5823
# 22                           Moisasurs Zauberfluch.txt   17912   5738
# 23                   Das MÑdchen aus der Feenwelt.txt   21040   6443
# 24         Der Barometermacher auf der Zauberinsel.txt   16032   5318
# 25                  Der Diamant des Geisterkînigs.txt   18855   5968
# 26                       Die unheilbringende Krone.txt   24701   7548
# 27           Der Alpenkînig und der Menschenfeind.txt   21802   6996
# 28                                         Othello.txt   16568   6793
# 29                        Der Kaufmann von Venedig.txt   20600   7121
# 30                           Ein Sommernachtstraum.txt   16648   6444
# ..                                                 ...     ...    ...
# 73                            Contes de la Becasse.txt   34723  10210
# 74                                  Claire de Lune.txt   25975   8076
# 75                                 La petite roque.txt   40688  10890
# 76                                        Le Horla.txt   41485  11091
# 77                               L'inutile beautÇ.txt   37840  10781
# 78                                   Boule de Suif.txt   35905  10725
# 79                               La Maison Tellier.txt   43685  12305
# 80                                  L'oiseau blanc.txt   21973   6337
# 81                      Les deux amis de Bourbonne.txt    8510   2929
# 82          Regrets sur ma vieille robe de chambre.txt    4980   1876
# 83                         Ceci n'est pas un conte.txt   10938   3674
# 84           Entretien d'un päre avec ses enfants.txt   11125   3720
# 85                     La fille des indiens rouges.txt   66621  17875
# 86                           Les derniers Iroquois.txt   55565  15583
# 87                                    La capitaine.txt   46306  13083
# 88                                Le chasseur noir.txt   51341  12945
# 89          L'enfer et le paradis de l'autre monde.txt   40827  10831
# 90                                 L'åle de sable.txt   73801  18989
# 91                              La fille du pirate.txt   52519  14649
# 92                              Le poâme de Myrza.txt   12771   4348
# 93   La Coupe; Lupo Liverani; Le Toast; Garnier; Le...   47831  12540
# 94                                    Le Piccinino.txt  151405  27435
# 95             Jacques le fataliste et son maåtre.txt   85756  18744
# 96                                         Pauline.txt   27486   7901
# 97                                            cora.txt   12370   4370
# 98                                     La Marquise.txt   14716   4786
# 99                                         L' Orco.txt    8748   3162
# 100                                         Mattea.txt   21089   6429
# 101                                        Metella.txt   19600   5715
# 102             Oeuvres illustrÇes de George Sand.txt   23210   7503
#
# [102 rows x 5 columns]

# %% [markdown]
# <font color=#0000ff size=4 face="黑体">对上面创建表格数据的代码作微小的改动，使得</font>
#
# 1）作者姓名的首字母大写
#
# 2）书名中没有.txt

# %%
# DataFrame.loc[]: Access a group of rows and columns by label(s) or a boolean array.
stats = pd.DataFrame(columns = ("language","author","title","length","unique"))
title_num = 1            


for language in os.listdir(book_dir):  # 将（）中的参数补充完整
    for author in os.listdir(book_dir+"/"+language):  #将（）中的参数补充完整
        for title in os.listdir(book_dir+"/"+language+"/"+author):  #将（）中的参数补充完整
            inputfile =  book_dir+language+"/"+author+"/"+title    # 给inputfile赋值
            text = read_book(inputfile)
            (num_unique,counts) = word_statistics(count_words_fast(text))
            stats.loc[title_num] = language, author.capitalize(), title.rstrip('.txt'), sum(counts), num_unique  # 补充完整赋值号右边
            title_num += 1

# %%
stats
# Out:
#     language         author  \
# 1     German       Schiller
# 2     German       Schiller
# 3     German       Schiller
# 4     German       Schiller
# 5     German       Schiller
# 6     German       Schiller
# 7     German       Schiller
# 8     German       Schiller
# 9     German       Schiller
# 10    German       Schiller
# 11    German       Schiller
# 12    German        Lessing
# 13    German        Lessing
# 14    German        Lessing
# 15    German        Lessing
# 16    German        Lessing
# 17    German        Lessing
# 18    German        Lessing
# 19    German        Lessing
# 20    German        Raimund
# 21    German        Raimund
# 22    German        Raimund
# 23    German        Raimund
# 24    German        Raimund
# 25    German        Raimund
# 26    German        Raimund
# 27    German        Raimund
# 28    German    Shakespeare
# 29    German    Shakespeare
# 30    German    Shakespeare
# ..       ...            ...
# 73    French  De maupassant
# 74    French  De maupassant
# 75    French  De maupassant
# 76    French  De maupassant
# 77    French  De maupassant
# 78    French  De maupassant
# 79    French  De maupassant
# 80    French        Diderot
# 81    French        Diderot
# 82    French        Diderot
# 83    French        Diderot
# 84    French        Diderot
# 85    French      Chevalier
# 86    French      Chevalier
# 87    French      Chevalier
# 88    French      Chevalier
# 89    French      Chevalier
# 90    French      Chevalier
# 91    French      Chevalier
# 92    French           Sand
# 93    French           Sand
# 94    French           Sand
# 95    French           Sand
# 96    French           Sand
# 97    French           Sand
# 98    French           Sand
# 99    French           Sand
# 100   French           Sand
# 101   French           Sand
# 102   French           Sand
#
#                                                  title  length unique
# 1                                   Wallensteins Lager   15443   4379
# 2                                die braut von messina   26482   6655
# 3    Der Parasit, oder die Kunst, sein GlÅck zu ma...   20450   6159
# 4                Die Verschwîrung des Fiesco zu Genua   31128  10371
# 5                                     Kabale und Liebe   30929   9969
# 6                            Die Huldigung der KÅnste    3919   1730
# 7                                  Der Neffe als Onkel   14349   4416
# 8                                      Die Piccolomini   35456   6763
# 9                             Die Jungfrau von Orleans   24181   8806
# 10                      Turandot, Prinzessin von China   21441   7550
# 11                                    Wallensteins Tod   50725   8649
# 12                                  minna von barnhelm   23863   7345
# 13                            hamburgische dramaturgie  143699  29192
# 14                                   miss sara sampson   28148   7231
# 15                                           die juden   12143   3887
# 16                                        der freigeis   23660   6319
# 17                                            philotas    9535   3278
# 18                                  der junge gelehrte   28155   7231
# 19                                      emilia galotti   20484   6631
# 20                                    Der Verschwender   25106   7423
# 21                            Die gefesselte Phantasie   16651   5823
# 22                               Moisasurs Zauberfluch   17912   5738
# 23                        Das MÑdchen aus der Feenwel   21040   6443
# 24             Der Barometermacher auf der Zauberinsel   16032   5318
# 25                      Der Diamant des Geisterkînigs   18855   5968
# 26                           Die unheilbringende Krone   24701   7548
# 27               Der Alpenkînig und der Menschenfeind   21802   6996
# 28                                             Othello   16568   6793
# 29                            Der Kaufmann von Venedig   20600   7121
# 30                               Ein Sommernachtstraum   16648   6444
# ..                                                 ...     ...    ...
# 73                                Contes de la Becasse   34723  10210
# 74                                      Claire de Lune   25975   8076
# 75                                     La petite roque   40688  10890
# 76                                            Le Horla   41485  11091
# 77                                   L'inutile beautÇ   37840  10781
# 78                                       Boule de Suif   35905  10725
# 79                                   La Maison Tellier   43685  12305
# 80                                      L'oiseau blanc   21973   6337
# 81                          Les deux amis de Bourbonne    8510   2929
# 82              Regrets sur ma vieille robe de chambre    4980   1876
# 83                             Ceci n'est pas un conte   10938   3674
# 84               Entretien d'un päre avec ses enfants   11125   3720
# 85                         La fille des indiens rouges   66621  17875
# 86                               Les derniers Iroquois   55565  15583
# 87                                        La capitaine   46306  13083
# 88                                    Le chasseur noir   51341  12945
# 89              L'enfer et le paradis de l'autre monde   40827  10831
# 90                                     L'åle de sable   73801  18989
# 91                                  La fille du pirate   52519  14649
# 92                                  Le poâme de Myrza   12771   4348
# 93   La Coupe; Lupo Liverani; Le Toast; Garnier; Le...   47831  12540
# 94                                        Le Piccinino  151405  27435
# 95                 Jacques le fataliste et son maåtre   85756  18744
# 96                                             Pauline   27486   7901
# 97                                                cora   12370   4370
# 98                                         La Marquise   14716   4786
# 99                                             L' Orco    8748   3162
# 100                                             Mattea   21089   6429
# 101                                            Metella   19600   5715
# 102                 Oeuvres illustrÇes de George Sand   23210   7503
#
# [102 rows x 5 columns]

# %% [markdown]
# <font color=#0000ff size=5 face="黑体"> 怎样查看一个名为stats的DataFrame中前几行和后几行的数据？</font>

# %%
# head([n])：Return the first n rows. If n is not given, it returns the top five lines
stats.head()
# Out:
#   language    author                                              title  \
# 1   German  Schiller                                 Wallensteins Lager
# 2   German  Schiller                              die braut von messina
# 3   German  Schiller  Der Parasit, oder die Kunst, sein GlÅck zu ma...
# 4   German  Schiller              Die Verschwîrung des Fiesco zu Genua
# 5   German  Schiller                                   Kabale und Liebe
#
#   length unique
# 1  15443   4379
# 2  26482   6655
# 3  20450   6159
# 4  31128  10371
# 5  30929   9969

# %%
stats.head(8)
# Out:
#   language    author                                              title  \
# 1   German  Schiller                                 Wallensteins Lager
# 2   German  Schiller                              die braut von messina
# 3   German  Schiller  Der Parasit, oder die Kunst, sein GlÅck zu ma...
# 4   German  Schiller              Die Verschwîrung des Fiesco zu Genua
# 5   German  Schiller                                   Kabale und Liebe
# 6   German  Schiller                          Die Huldigung der KÅnste
# 7   German  Schiller                                Der Neffe als Onkel
# 8   German  Schiller                                    Die Piccolomini
#
#   length unique
# 1  15443   4379
# 2  26482   6655
# 3  20450   6159
# 4  31128  10371
# 5  30929   9969
# 6   3919   1730
# 7  14349   4416
# 8  35456   6763

# %%
# tail([n]): Return the last n rows.If n is not given, it returns the bottom five lines
stats.tail()
# Out:
#     language author                               title length unique
# 98    French   Sand                         La Marquise  14716   4786
# 99    French   Sand                             L' Orco   8748   3162
# 100   French   Sand                              Mattea  21089   6429
# 101   French   Sand                             Metella  19600   5715
# 102   French   Sand  Oeuvres illustrÇes de George Sand  23210   7503

# %%
stats.tail(3)
# Out:
#     language author                               title length unique
# 100   French   Sand                              Mattea  21089   6429
# 101   French   Sand                             Metella  19600   5715
# 102   French   Sand  Oeuvres illustrÇes de George Sand  23210   7503

# %% [markdown]
# <font color=#0000ff size=5 face="黑体"> 学习怎样使用matplotlib.pyplot画出书籍的长度和单词频率统计图。</font>

# %%
# The matplotlib.pyplot module contains functions that
# allow you to generate many kinds of plots quickly
import matplotlib.pyplot as plt
plt.plot(stats.length,stats.unique,"bo")
plt.show()

# %%
# use the loglog version, which plots both x and y-axis logarithmically.
plt.plot(stats.length,stats.unique,"bo")
plt.loglog(stats.length,stats.unique,"bo")
plt.show()

# %%
# look at these elements for which language is equal to English
stats[stats.language == "English"]
# Out:
#    language       author                      title length unique
# 35  English  Shakespeare                    Othello  26590   5898
# 36  English  Shakespeare                Richard III  48315   5449
# 37  English  Shakespeare     The Merchant of Venice  20949   4978
# 38  English  Shakespeare  A Midsummer Night's Dream  16103   4345
# 39  English  Shakespeare                    Macbeth  16874   4780
# 40  English  Shakespeare                      Hamle  28551   6776
# 41  English  Shakespeare            Romeo and Julie  40776   5118

# %%
# look at these elements for which language is equal to French
stats[stats.language == "French"]
# Out:
#     language         author  \
# 71    French  De maupassant
# 72    French  De maupassant
# 73    French  De maupassant
# 74    French  De maupassant
# 75    French  De maupassant
# 76    French  De maupassant
# 77    French  De maupassant
# 78    French  De maupassant
# 79    French  De maupassant
# 80    French        Diderot
# 81    French        Diderot
# 82    French        Diderot
# 83    French        Diderot
# 84    French        Diderot
# 85    French      Chevalier
# 86    French      Chevalier
# 87    French      Chevalier
# 88    French      Chevalier
# 89    French      Chevalier
# 90    French      Chevalier
# 91    French      Chevalier
# 92    French           Sand
# 93    French           Sand
# 94    French           Sand
# 95    French           Sand
# 96    French           Sand
# 97    French           Sand
# 98    French           Sand
# 99    French           Sand
# 100   French           Sand
# 101   French           Sand
# 102   French           Sand
#
#                                                  title  length unique
# 71               Œuvres complètes de Guy de Maupassan   54772  15028
# 72                                      La Main Gauche   33481   9983
# 73                                Contes de la Becasse   34723  10210
# 74                                      Claire de Lune   25975   8076
# 75                                     La petite roque   40688  10890
# 76                                            Le Horla   41485  11091
# 77                                   L'inutile beautÇ   37840  10781
# 78                                       Boule de Suif   35905  10725
# 79                                   La Maison Tellier   43685  12305
# 80                                      L'oiseau blanc   21973   6337
# 81                          Les deux amis de Bourbonne    8510   2929
# 82              Regrets sur ma vieille robe de chambre    4980   1876
# 83                             Ceci n'est pas un conte   10938   3674
# 84               Entretien d'un päre avec ses enfants   11125   3720
# 85                         La fille des indiens rouges   66621  17875
# 86                               Les derniers Iroquois   55565  15583
# 87                                        La capitaine   46306  13083
# 88                                    Le chasseur noir   51341  12945
# 89              L'enfer et le paradis de l'autre monde   40827  10831
# 90                                     L'åle de sable   73801  18989
# 91                                  La fille du pirate   52519  14649
# 92                                  Le poâme de Myrza   12771   4348
# 93   La Coupe; Lupo Liverani; Le Toast; Garnier; Le...   47831  12540
# 94                                        Le Piccinino  151405  27435
# 95                 Jacques le fataliste et son maåtre   85756  18744
# 96                                             Pauline   27486   7901
# 97                                                cora   12370   4370
# 98                                         La Marquise   14716   4786
# 99                                             L' Orco    8748   3162
# 100                                             Mattea   21089   6429
# 101                                            Metella   19600   5715
# 102                 Oeuvres illustrÇes de George Sand   23210   7503

# %%
# construct a plot using different colors for different language
# plt using the same names for colors as HTML does.
plt.figure(figsize=(10,10))
subset = stats[stats.language == "English"]
plt.loglog(subset.length,subset.unique,"o",label="English",color="crimson")

subset = stats[stats.language == "French"]
plt.loglog(subset.length,subset.unique,"o",label="French",color="forestgreen")

subset = stats[stats.language == "German"]
plt.loglog(subset.length,subset.unique,"o",label="German",color="orange")

subset = stats[stats.language == "Portuguese"]
plt.loglog(subset.length,subset.unique,"o",label="Portuguese",color="blueviolet")

plt.legend()
plt.xlabel("Book length")
plt.ylabel("Number of unique words")
plt.savefig("lang_plot.pdf")
plt.show()
